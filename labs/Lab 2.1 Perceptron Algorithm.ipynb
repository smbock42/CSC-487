# %% [markdown]
# ### Lab 2.1: Perceptron Algorithm - Solution
#
# In this lab you will implement the perceptron algorithm presented in lecture using NumPy.

# %%
import numpy as np
from palmerpenguins import load_penguins
from mlxtend.plotting import plot_decision_regions
from matplotlib import pyplot as plt

# %% [markdown]
# Here we loading and format the Palmer penguins dataset for binary classification.

# %%
df = load_penguins()

# drop rows with missing values
df.dropna(inplace=True)

# tricky code to randomly shuffle the rows
df = df.sample(frac=1).reset_index(drop=True)

# select only two specices
df = df[(df['species']=='Adelie')|(df['species']=='Chinstrap')]

# get two features
X = df[['flipper_length_mm','bill_length_mm']].values

# convert speces labels to -1 and 1
y = df['species'].map({'Adelie':-1,'Chinstrap':1}).values

# %% [markdown]
# To make the learning algorithm work more smoothly, we we will subtract the mean of each feature.
#
# Here `np.mean` calculates a mean, and `axis=0` tells NumPy to calculate the mean over the rows (calculate the mean of each column).

# %%
X -= np.mean(X,axis=0)

# %% [markdown]
# ### Exercises
#
# Your task is to complete this class for the perceptron.  Fill in the `train_step`, `predict`, and `score` functions.

# %%
class Perceptron:
    def __init__(self,lr=1e-3):
        # store the learning rate
        self.lr = lr

        # initialize the weights to small, normally-distributed values
        self.w = np.random.normal(size=(2,))*0.01

        # initialize the bias to zero
        self.b = 0

    def train_step(self,x,y):
        """ Apply the first update rule shown in lecture.
            Arguments:
             x: data point of shape (2,)
             y: label 
        """
        # WRITE CODE HERE
        z = np.dot(self.w, x) + self.b
        
        if y*z <= 0:
            self.w += self.lr * y * x
            self.b += self.lr * y
    
    def predict(self,X):
        """ Calculate model prediction for all data points.
            
            Arguments:
             X: data matrix of shape (N,2)   
            Returns:
             Predicted labels (-1 or 1) of shape (N,)
        """
        # WRITE CODE HERE
        # Hint: look at np.where
        z = np.dot(X, self.w) + self.b
        return np.where(z>=0, 1, -1)
        
    
    def score(self,X,y):
        """ Calculate model accuracy
            Arguments:
             X: data matrix of shape (N,2)   
             y: labels of shape (N,)
            Returns:
             Accuracy score
        """
        # WRITE CODE HERE
        y_pred = self.predict(X)
        return np.mean(y_pred == y)

# %% [markdown]
# Run the following code to train the model and print out the accuracy at each step.

# %%
model = Perceptron()
for i in range(len(X)):
    model.train_step(X[i],y[i])
    print(f'step {i}: {model.score(X,y)}')
# Out:
# step 0: 0.2336448598130841
# step 1: 0.5700934579439252
# step 2: 0.20093457943925233
# step 3: 0.7476635514018691
# step 4: 0.7663551401869159
# step 5: 0.7663551401869159
# step 6: 0.7663551401869159
# step 7: 0.7663551401869159
# step 8: 0.7663551401869159
# step 9: 0.7663551401869159
# step 10: 0.7663551401869159
# step 11: 0.7663551401869159
# step 12: 0.7663551401869159
# step 13: 0.7663551401869159
# step 14: 0.7663551401869159
# step 15: 0.7663551401869159
# step 16: 0.7663551401869159
# step 17: 0.7663551401869159
# step 18: 0.780373831775701
# step 19: 0.780373831775701
# step 20: 0.780373831775701
# step 21: 0.8598130841121495
# step 22: 0.8598130841121495
# step 23: 0.8598130841121495
# step 24: 0.8598130841121495
# step 25: 0.8598130841121495
# step 26: 0.8551401869158879
# step 27: 0.8551401869158879
# step 28: 0.8551401869158879
# step 29: 0.8551401869158879
# step 30: 0.8785046728971962
# step 31: 0.9345794392523364
# step 32: 0.9345794392523364
# step 33: 0.9345794392523364
# step 34: 0.9345794392523364
# step 35: 0.9345794392523364
# step 36: 0.9345794392523364
# step 37: 0.9345794392523364
# step 38: 0.9345794392523364
# step 39: 0.9345794392523364
# step 40: 0.9345794392523364
# step 41: 0.9345794392523364
# step 42: 0.9345794392523364
# step 43: 0.9345794392523364
# step 44: 0.9345794392523364
# step 45: 0.9345794392523364
# step 46: 0.9345794392523364
# step 47: 0.9345794392523364
# step 48: 0.9345794392523364
# step 49: 0.9345794392523364
# step 50: 0.9345794392523364
# step 51: 0.9345794392523364
# step 52: 0.9345794392523364
# step 53: 0.9345794392523364
# step 54: 0.8317757009345794
# step 55: 0.8317757009345794
# step 56: 0.8317757009345794
# step 57: 0.9158878504672897
# step 58: 0.9158878504672897
# step 59: 0.9158878504672897
# step 60: 0.9158878504672897
# step 61: 0.9158878504672897
# step 62: 0.9158878504672897
# step 63: 0.9252336448598131
# step 64: 0.9252336448598131
# step 65: 0.9252336448598131
# step 66: 0.9252336448598131
# step 67: 0.9252336448598131
# step 68: 0.9252336448598131
# step 69: 0.9252336448598131
# step 70: 0.9252336448598131
# step 71: 0.9252336448598131
# step 72: 0.8364485981308412
# step 73: 0.8364485981308412
# step 74: 0.8364485981308412
# step 75: 0.8364485981308412
# step 76: 0.8364485981308412
# step 77: 0.8364485981308412
# step 78: 0.8598130841121495
# step 79: 0.8598130841121495
# step 80: 0.8598130841121495
# step 81: 0.8598130841121495
# step 82: 0.9252336448598131
# step 83: 0.9252336448598131
# step 84: 0.6355140186915887
# step 85: 0.6355140186915887
# step 86: 0.6355140186915887
# step 87: 0.9345794392523364
# step 88: 0.9345794392523364
# step 89: 0.9345794392523364
# step 90: 0.9345794392523364
# step 91: 0.9345794392523364
# step 92: 0.9345794392523364
# step 93: 0.9345794392523364
# step 94: 0.9345794392523364
# step 95: 0.9345794392523364
# step 96: 0.9345794392523364
# step 97: 0.9345794392523364
# step 98: 0.9345794392523364
# step 99: 0.9345794392523364
# step 100: 0.9345794392523364
# step 101: 0.9345794392523364
# step 102: 0.9345794392523364
# step 103: 0.9345794392523364
# step 104: 0.9345794392523364
# step 105: 0.9345794392523364
# step 106: 0.9345794392523364
# step 107: 0.9345794392523364
# step 108: 0.9345794392523364
# step 109: 0.9345794392523364
# step 110: 0.9345794392523364
# step 111: 0.9345794392523364
# step 112: 0.9345794392523364
# step 113: 0.9345794392523364
# step 114: 0.822429906542056
# step 115: 0.822429906542056
# step 116: 0.9252336448598131
# step 117: 0.9252336448598131
# step 118: 0.9252336448598131
# step 119: 0.9252336448598131
# step 120: 0.9252336448598131
# step 121: 0.9252336448598131
# step 122: 0.9252336448598131
# step 123: 0.9392523364485982
# step 124: 0.9392523364485982
# step 125: 0.9392523364485982
# step 126: 0.9392523364485982
# step 127: 0.9392523364485982
# step 128: 0.9392523364485982
# step 129: 0.9392523364485982
# step 130: 0.9392523364485982
# step 131: 0.9392523364485982
# step 132: 0.9392523364485982
# step 133: 0.9392523364485982
# step 134: 0.9485981308411215
# step 135: 0.9485981308411215
# step 136: 0.9485981308411215
# step 137: 0.9485981308411215
# step 138: 0.9485981308411215
# step 139: 0.9485981308411215
# step 140: 0.9485981308411215
# step 141: 0.9485981308411215
# step 142: 0.9485981308411215
# step 143: 0.9485981308411215
# step 144: 0.9485981308411215
# step 145: 0.9485981308411215
# step 146: 0.9485981308411215
# step 147: 0.9485981308411215
# step 148: 0.9485981308411215
# step 149: 0.9485981308411215
# step 150: 0.9485981308411215
# step 151: 0.9485981308411215
# step 152: 0.9485981308411215
# step 153: 0.9485981308411215
# step 154: 0.9485981308411215
# step 155: 0.9485981308411215
# step 156: 0.9485981308411215
# step 157: 0.9485981308411215
# step 158: 0.8598130841121495
# step 159: 0.8504672897196262
# step 160: 0.8504672897196262
# step 161: 0.8551401869158879
# step 162: 0.8551401869158879
# step 163: 0.8551401869158879
# step 164: 0.8551401869158879
# step 165: 0.8551401869158879
# step 166: 0.8551401869158879
# step 167: 0.8551401869158879
# step 168: 0.8551401869158879
# step 169: 0.8551401869158879
# step 170: 0.9112149532710281
# step 171: 0.9112149532710281
# step 172: 0.9112149532710281
# step 173: 0.9112149532710281
# step 174: 0.9112149532710281
# step 175: 0.9112149532710281
# step 176: 0.9112149532710281
# step 177: 0.9112149532710281
# step 178: 0.9112149532710281
# step 179: 0.9112149532710281
# step 180: 0.9112149532710281
# step 181: 0.9112149532710281
# step 182: 0.9112149532710281
# step 183: 0.9112149532710281
# step 184: 0.9112149532710281
# step 185: 0.9112149532710281
# step 186: 0.9112149532710281
# step 187: 0.9112149532710281
# step 188: 0.9112149532710281
# step 189: 0.9112149532710281
# step 190: 0.9112149532710281
# step 191: 0.9112149532710281
# step 192: 0.9112149532710281
# step 193: 0.9112149532710281
# step 194: 0.9112149532710281
# step 195: 0.9112149532710281
# step 196: 0.9112149532710281
# step 197: 0.9626168224299065
# step 198: 0.9626168224299065
# step 199: 0.9626168224299065
# step 200: 0.9626168224299065
# step 201: 0.9626168224299065
# step 202: 0.9626168224299065
# step 203: 0.9626168224299065
# step 204: 0.9626168224299065
# step 205: 0.9626168224299065
# step 206: 0.9626168224299065
# step 207: 0.9626168224299065
# step 208: 0.9626168224299065
# step 209: 0.9626168224299065
# step 210: 0.9626168224299065
# step 211: 0.9626168224299065
# step 212: 0.9626168224299065
# step 213: 0.9626168224299065

# %% [markdown]
# Finally we plot the decision regions.  (The blue part isn't shown because it doesn't like the -1 label.)

# %%
plot_decision_regions(X, y, clf=model, legend=0, markers='o')
# Out:
# <Axes: >
